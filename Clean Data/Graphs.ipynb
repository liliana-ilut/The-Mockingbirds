# %%
#Import Dependencies 

import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import datetime as dt

# %%
# Take in all of our data and read it into pandas

csvpath = "./Resources/AllMerge.csv"

combined_df = pd.read_csv(csvpath)
combined_df.head(3)
# Out:
#                       Location  Population  Obesity Percentage  Lower Limit  \
# 0  LosAngelesCounty,California    10105518                21.4         20.2
# 1          CookCounty,Illinois     5180493                27.7         26.5
# 2           HarrisCounty,Texas     4698619                27.6         25.5
#
#    Upper Limit  Household Total  Median   Mean  NAICS Code  \
# 0         22.7          3305589   61338  89718        7225
# 1         29.0          1963973   60046  86514        7225
# 2         29.7          1606399   56377  84551        7225
#
#                      NAICS Description  Total CBP and NES Establishments  \
# 0  Restaurants and Other Eating Places                           23519.0
# 1  Restaurants and Other Eating Places                           12157.0
# 2  Restaurants and Other Eating Places                            9494.0
#
#    CBP Establishments Percentage  NES Establishments Percentage  \
# 0                           82.2                           17.8
# 1                           80.9                           19.1
# 2                           76.9                           23.1
#
#    CBP Establishments
# 0             19334.0
# 1              9839.0
# 2              7297.0

# %%
# the x and y values (x=population, y= obesity)
pop = combined_df ["Population"]
ob = combined_df["Obesity Percentage"]

#create the scatter plt, modify colors, grid and create labels for axis and title
plt.scatter(pop, ob,color="coral", edgecolors="grey", alpha=0.75)
plt.xlabel("Population")
plt.ylabel("Obesity Percentage")
plt.title("Population vs Obesity")
plt.grid()

#save figure as .png file in Figures folder and show the figure on the script
# plt.savefig("Figures/Plot_Lat_vs_Temp.png")
plt.show()

# %%
# the x and y values (x=population, y= obesity)
pop = combined_df ["Population"]
ob = combined_df["Obesity Percentage"]

#create the linear regression equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(pop, ob)
regress_values = pop * slope + intercept
line_eq = "y = " + str(round(slope,4)) + "x + " + str(round(intercept,4))

plt.scatter(pop, ob,color="coral", edgecolors="grey", alpha=0.75)
plt.plot(pop,regress_values,"r-")
plt.annotate(line_eq,(1,10), fontsize = 15, color = "red")

#create the scatter plt, modify colors, grid and create labels for axis and title

plt.xlabel("Population")
plt.ylabel("Obesity Percentage")
plt.title(" Linear Regression Population vs Obesity")
plt.grid()

print(f" Linear Equation is : {line_eq}")
print(f" R-squared is {rvalue**2}")

#save figure as .png file in Figures folder and show the figure on the script
# plt.savefig("Figures/Plot_Lat_vs_Temp.png")
plt.show()
# Out:
#  Linear Equation is : y = -0.0x + 29.1095
#  R-squared is 0.06856009925207514

# %%
# the x and y values (x=population, y= obesity)
pop = combined_df ["Population"]
inc = combined_df["Median"]

#create the scatter plt, modify colors, grid and create labels for axis and title
plt.scatter(pop, inc,color="green", edgecolors="black", alpha=0.75)
plt.xlabel("Population")
plt.ylabel("Median")
plt.title("Population vs Median Income")
plt.grid()

#save figure as .png file in Figures folder and show the figure on the script
# plt.savefig("Figures/Plot_Lat_vs_Temp.png")
plt.show()

# %%
# the x and y values (x=population, y= obesity)
rest = combined_df ["Total CBP and NES Establishments"]
inc = combined_df["Median"]

#create the scatter plt, modify colors, grid and create labels for axis and title
plt.scatter(rest, inc,color="coral", edgecolors="black", alpha=0.75)
plt.xlabel("Total CBP and NES Establishments")
plt.ylabel("Median")
plt.title("Restaurant  vs Median Income")
plt.grid()

#save figure as .png file in Figures folder and show the figure on the script
# plt.savefig("Figures/Plot_Lat_vs_Temp.png")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = combined_df["Median"]
y = combined_df["Obesity Percentage"]
z = x/y

fig = plt.figure(figsize=(6, 6))
plt.scatter(x, y,
           linewidths=1, alpha=.7,
           edgecolor='k',
           s = 200,
           c=z)
plt.show()

# %%
# the x and y values (x=population, y= obesity)
obe = combined_df ["Obesity Percentage"]
inc = combined_df["Median"]

#create the scatter plt, modify colors, grid and create labels for axis and title
plt.scatter(rest, inc,color="coral", edgecolors="black", alpha=0.75)
plt.xlabel("Obesity Percentage")
plt.ylabel("Median")
plt.title("Obesity  vs Median Income")
plt.grid()

#save figure as .png file in Figures folder and show the figure on the script
# plt.savefig("Figures/Plot_Lat_vs_Temp.png")
plt.show()

# %%
# the x and y values (x=population, y= obesity)
obe = combined_df ["Obesity Percentage"]
inc = combined_df["Median"]

#create the linear regression equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(obe, inc)
regress_values = obe * slope + intercept
line_eq = "y = " + str(round(slope,4)) + "x + " + str(round(intercept,4))

plt.scatter(obe, inc,color="lightgreen", edgecolors="grey", alpha=0.75)
plt.plot(obe,regress_values,"r-")
plt.annotate(line_eq,(10,50), fontsize = 15, color = "red")

#create the scatter plt, modify colors, grid and create labels for axis and title

plt.xlabel("Obesity Percentage")
plt.ylabel("Median")
plt.title(" Linear Regression Obesity vs Income")
plt.grid()

print(f" Linear Equation is : {line_eq}")
print(f" R-squared is {rvalue**2}")

#save figure as .png file in Figures folder and show the figure on the script
# plt.savefig("Figures/Plot_Lat_vs_Temp.png")
plt.show()
# Out:
#  Linear Equation is : y = -2164.3459x + 125541.7346
#  R-squared is 0.34414871800947006

# %%
# the x and y values (x=population, y= obesity)
pop = combined_df ["Population"]
inc = combined_df["Median"]

#create the scatter plt, modify colors, grid and create labels for axis and title
plt.scatter(pop, inc,cmap="plasma", edgecolors="grey", alpha=0.75, linewidth=2)
plt.xlabel("Population")
plt.ylabel("Median")
plt.title("Population vs Median Income")
plt.grid()

#save figure as .png file in Figures folder and show the figure on the script
# plt.savefig("Figures/Plot_Lat_vs_Temp.png")
plt.show()

# %%
# the x and y values (x=population, y= obesity)
rest = combined_df["Total CBP and NES Establishments"]
obe = combined_df ["Obesity Percentage"]


#create the scatter plt, modify colors, grid and create labels for axis and title
plt.scatter(obe, rest,color="coral", edgecolors="black", alpha=0.75)
plt.xlabel("Obesity Percentage")
plt.ylabel("Restaurants")
plt.title("Obesity vs Restaurants")
# plt.grid()

#save figure as .png file in Figures folder and show the figure on the script
# plt.savefig("Figures/Plot_Lat_vs_Temp.png")
plt.show()

# %%
# the x and y values (x=population, y= obesity)
rest = combined_df["Total CBP and NES Establishments"]
obe = combined_df ["Obesity Percentage"]

#create the linear regression equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(obe, rest)
regress_values = obe * slope + intercept
line_eq = "y = " + str(round(slope,4)) + "x + " + str(round(intercept,4))

plt.scatter(obe, rest,color="coral", edgecolors="grey", alpha=0.75)
plt.plot(obe,regress_values,"r-")
plt.annotate(line_eq,(1,10), fontsize = 15, color = "red")

#create the scatter plt, modify colors, grid and create labels for axis and title

plt.xlabel("Obesity Percentage")
plt.ylabel("Total CBP and NES Establishments")
plt.title(" Linear Regression Obesity vs Restaurants")
plt.grid()

print(f" Linear Equation is : {line_eq}")
print(f" R-squared is {rvalue**2}")

#save figure as .png file in Figures folder and show the figure on the script
# plt.savefig("Figures/Plot_Lat_vs_Temp.png")
plt.show()
# Out:
#  Linear Equation is : y = -143.2588x + 5558.904
#  R-squared is 0.10702800731725814

# %%
# the x and y values (x=population, y= obesity)
pop = combined_df ["Population"]
rest = combined_df["Total CBP and NES Establishments"]

#create the scatter plt, modify colors, grid and create labels for axis and title
plt.scatter(pop, rest,color="coral", edgecolors="black", alpha=0.75)
plt.xlabel("Population")
plt.ylabel("Total CBP and NES Establishments")
plt.title("Population vs Restaurants")
# plt.grid()

#save figure as .png file in Figures folder and show the figure on the script
# plt.savefig("Figures/Plot_Lat_vs_Temp.png")
plt.show()

# %%
# the x and y values (x=population, y= obesity)
pop = combined_df ["Population"]
rest = combined_df["Total CBP and NES Establishments"]

#create the linear regression equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(pop, rest)
regress_values = pop * slope + intercept
line_eq = "y = " + str(round(slope,4)) + "x + " + str(round(intercept,4))

plt.scatter(pop, rest,color="coral", edgecolors="grey", alpha=0.75)
plt.plot(pop,regress_values,"r-")
plt.annotate(line_eq,(1,10), fontsize = 15, color = "red")

#create the scatter plt, modify colors, grid and create labels for axis and title

plt.xlabel("Population")
plt.ylabel("Restaurants")
plt.title(" Linear Regression Population vs Restaurant")
plt.grid()

print(f" Linear Equation is : {line_eq}")
print(f" R-squared is {rvalue**2}")

#save figure as .png file in Figures folder and show the figure on the script
# plt.savefig("Figures/Plot_Lat_vs_Temp.png")
plt.show()
# Out:
#  Linear Equation is : y = 0.0023x + -130.3885
#  R-squared is 0.9413627072725893

# %%
location_data = combined_df["Location"].value_counts()
population_data = combined_df["Population"].value_counts()
total_data = location_data.add(population_data, fill_value = 0)

total_data.plot(kind = "bar", facecolor = "red")
plt.tight_layout()

# %%
TotalPop = float((combined_df["Population"]).sum())
TotalPop
# Out:
# 207592477.0

# %%
TotalInc = float((combined_df["Median"]).sum())
TotalInc
# Out:
# 18327388.0

# %%
TotalRest = float((combined_df["CBP Establishments"]).sum())
TotalRest
# Out:
# 368007.0

# %%
HighToLowIncome_df = combined_df.sort_values(["Median"], ascending=False).head()
HighToLowIncome_df
# Out:
#                         Location  Population  Obesity Percentage  Lower Limit  \
# 165       LoudounCounty,Virginia      406850                22.1         18.9
# 207        HowardCounty,Maryland      323196                24.8         22.4
# 37        FairfaxCounty,Virginia     1150795                21.3         19.3
# 17   SantaClaraCounty,California     1937570                19.2         17.2
# 262     ArlingtonCounty,Virginia      237521                20.0         17.0
#
#      Upper Limit  Household Total  Median    Mean  NAICS Code  \
# 165         25.1           124916  134464  152447        7225
# 207         27.3           112542  120941  144125        7225
# 37          23.3           395164  115717  147335        7225
# 17          21.3           635687  111069  146813        7225
# 262         23.3           103479  110388  143507        7225
#
#                        NAICS Description  Total CBP and NES Establishments  \
# 165  Restaurants and Other Eating Places                             743.0
# 207  Restaurants and Other Eating Places                             602.0
# 37   Restaurants and Other Eating Places                            2345.0
# 17   Restaurants and Other Eating Places                            4365.0
# 262  Restaurants and Other Eating Places                             625.0
#
#      CBP Establishments Percentage  NES Establishments Percentage  \
# 165                           87.1                           12.9
# 207                           83.6                           16.4
# 37                            84.1                           15.9
# 17                            90.3                            9.7
# 262                           88.6                           11.4
#
#      CBP Establishments
# 165               647.0
# 207               503.0
# 37               1973.0
# 17               3943.0
# 262               554.0

# %%
LowToLowHigh_df = combined_df.sort_values(["Median"], ascending=True).head()
LowToLowHigh_df
# Out:
#                  Location  Population  Obesity Percentage  Lower Limit  \
# 235      WebbCounty,Texas      275910                37.7         27.5
# 63    HidalgoCounty,Texas      865939                34.4         29.3
# 158   CameronCounty,Texas      423908                30.9         25.5
# 27    BronxCounty,NewYork     1432132                28.8         26.3
# 187  MarionCounty,Florida      359977                30.7         27.7
#
#      Upper Limit  Household Total  Median   Mean  NAICS Code  \
# 235         49.2            73483   35659  53833        7225
# 63          40.1           234716   36176  53230        7225
# 158         36.7           120499   37061  51206        7225
# 27          31.7           498539   37525  53466        7225
# 187         34.1           134239   39383  54181        7225
#
#                        NAICS Description  Total CBP and NES Establishments  \
# 235  Restaurants and Other Eating Places                             591.0
# 63   Restaurants and Other Eating Places                            1483.0
# 158  Restaurants and Other Eating Places                             842.0
# 27   Restaurants and Other Eating Places                            2822.0
# 187  Restaurants and Other Eating Places                             470.0
#
#      CBP Establishments Percentage  NES Establishments Percentage  \
# 235                           61.1                           38.9
# 63                            59.8                           40.2
# 158                           65.3                           34.7
# 27                            60.7                           39.3
# 187                           83.2                           16.8
#
#      CBP Establishments
# 235               361.0
# 63                887.0
# 158               550.0
# 27               1713.0
# 187               391.0

# %%
counties = ["WebbCounty,Texas", "HidalgoCounty,Texas", "CameronCounty,Texas", "BronxCounty,NewYork", "MarionCounty,Florida",
            "ArlingtonCounty,Virginia","SantaClaraCounty,California", "FairfaxCounty,Virginia,", "HowardCounty,Maryland", "LoudounCounty,Virginia"]
median_income = [35659, 36176, 37061, 37525,39383, 
                 110388, 111069, 115717, 120941, 134464 ]
LowToHighInc_df = pd.DataFrame({ "Median": median_income}, index=counties)
LowToHighInc_df
LowToHighInc_df.plot.bar(rot=90, facecolor = "green", alpha = 0.5)
plt.title("Low to High Median Income per County (Loweste 5 and highest 5)")
plt.xlabel("Counties")
plt.ylabel("Median Income")
# Out:
# Text(0, 0.5, 'Median Income')

# %%
counties_df= HighToLowIncome_df.iloc[0]
counties_df
# Out:
# Location                                         LoudounCounty,Virginia
# Population                                                       406850
# Obesity Percentage                                                 22.1
# Lower Limit                                                        18.9
# Upper Limit                                                        25.1
# Household Total                                                  124916
# Median                                                           134464
# Mean                                                             152447
# NAICS Code                                                         7225
# NAICS Description                   Restaurants and Other Eating Places
# Total CBP and NES Establishments                                    743
# CBP Establishments Percentage                                      87.1
# NES Establishments Percentage                                      12.9
# CBP Establishments                                                  647
# Name: 165, dtype: object

# %%
HighToLowObe_df = combined_df.sort_values(["Obesity Percentage"], ascending=False).head()
HighToLowObe_df
# Out:
#                      Location  Population  Obesity Percentage  Lower Limit  \
# 281  MontgomeryCounty,Alabama      225763                37.7         34.0
# 235          WebbCounty,Texas      275910                37.7         27.5
# 88         PolkCounty,Florida      708009                37.6         34.6
# 145   TulareCounty,California      465861                37.1         30.7
# 263   HindsCounty,Mississippi      237085                37.0         33.5
#
#      Upper Limit  Household Total  Median   Mean  NAICS Code  \
# 281         41.2            90827   45395  65678        7225
# 235         49.2            73483   35659  53833        7225
# 88          40.9           226429   46355  61587        7225
# 145         44.0           135648   45881  61897        7225
# 263         40.7            91065   43657  62946        7225
#
#                        NAICS Description  Total CBP and NES Establishments  \
# 281  Restaurants and Other Eating Places                             452.0
# 235  Restaurants and Other Eating Places                             591.0
# 88   Restaurants and Other Eating Places                             871.0
# 145  Restaurants and Other Eating Places                             647.0
# 263  Restaurants and Other Eating Places                             476.0
#
#      CBP Establishments Percentage  NES Establishments Percentage  \
# 281                           87.4                           12.6
# 235                           61.1                           38.9
# 88                            76.7                           23.3
# 145                           84.5                           15.5
# 263                           79.6                           20.4
#
#      CBP Establishments
# 281               395.0
# 235               361.0
# 88                668.0
# 145               547.0
# 263               379.0

# %%
LowToLowHigh_df = combined_df.sort_values(["Obesity Percentage"], ascending=True).head()
LowToLowHigh_df
# Out:
#                           Location  Population  Obesity Percentage  \
# 20           NewYorkCounty,NewYork     1628701                14.7
# 203         BoulderCounty,Colorado      326078                15.1
# 250         MarinCounty,California      259666                15.7
# 86           DenverCounty,Colorado      716492                17.0
# 61   SanFranciscoCounty,California      883305                18.5
#
#      Lower Limit  Upper Limit  Household Total  Median    Mean  NAICS Code  \
# 20          13.5         16.0           748293   77559  143741        7225
# 203         13.4         17.0           123820   74615  105099        7225
# 250         11.9         20.1           106333  103845  160053        7225
# 86          15.8         18.4           292003   61105   90835        7225
# 61          15.9         21.4           358703  103801  144957        7225
#
#                        NAICS Description  Total CBP and NES Establishments  \
# 20   Restaurants and Other Eating Places                            9260.0
# 203  Restaurants and Other Eating Places                             801.0
# 250  Restaurants and Other Eating Places                             680.0
# 86   Restaurants and Other Eating Places                            1938.0
# 61   Restaurants and Other Eating Places                            3809.0
#
#      CBP Establishments Percentage  NES Establishments Percentage  \
# 20                            89.4                           10.6
# 203                           91.6                            8.4
# 250                           89.7                           10.3
# 86                            90.6                            9.4
# 61                            90.8                            9.2
#
#      CBP Establishments
# 20               8277.0
# 203               734.0
# 250               610.0
# 86               1756.0
# 61               3459.0

# %%
counties = ["NewYorkCounty,NewYork","BoulderCounty,Colorado", "MarinCounty,California", "DenverCounty,Colorado", "SanFranciscoCounty,California", "HindsCounty,Mississippi","TulareCounty,California", "PolkCounty,Florida","WebbCounty,Texas", "MontgomeryCounty,Alabama" ]
obesity_percentage = [14.7, 15.1, 15.7, 17.0, 18.5, 37.0 ,37.1, 37.6,37.7, 37.7  ]
HighestObe_df = pd.DataFrame({ "Obesity Percentage": obesity_percentage}, index=counties)
HighestObe_df
HighestObe_df.plot.bar(rot=90, facecolor = "orange", alpha = 0.5)
plt.title("Highest Obesity Percentage per County (Loweste 5 and highest 5)")
plt.xlabel("Counties")
plt.ylabel("Obesity Percentage")
# Out:
# Text(0, 0.5, 'Obesity Percentage')

# %%
HighToLowRest_df = combined_df.sort_values(["Total CBP and NES Establishments"], ascending=False).head()
HighToLowRest_df 
#Los Angeles County wins at higher population and higher number of restaurants
# Out:
#                        Location  Population  Obesity Percentage  Lower Limit  \
# 0   LosAngelesCounty,California    10105518                21.4         20.2
# 1           CookCounty,Illinois     5180493                27.7         26.5
# 2            HarrisCounty,Texas     4698619                27.6         25.5
# 20        NewYorkCounty,NewYork     1628701                14.7         13.5
# 5       OrangeCounty,California     3185968                19.0         17.3
#
#     Upper Limit  Household Total  Median    Mean  NAICS Code  \
# 0          22.7          3305589   61338   89718        7225
# 1          29.0          1963973   60046   86514        7225
# 2          29.7          1606399   56377   84551        7225
# 20         16.0           748293   77559  143741        7225
# 5          20.8          1032218   81837  113420        7225
#
#                       NAICS Description  Total CBP and NES Establishments  \
# 0   Restaurants and Other Eating Places                           23519.0
# 1   Restaurants and Other Eating Places                           12157.0
# 2   Restaurants and Other Eating Places                            9494.0
# 20  Restaurants and Other Eating Places                            9260.0
# 5   Restaurants and Other Eating Places                            7802.0
#
#     CBP Establishments Percentage  NES Establishments Percentage  \
# 0                            82.2                           17.8
# 1                            80.9                           19.1
# 2                            76.9                           23.1
# 20                           89.4                           10.6
# 5                            87.8                           12.2
#
#     CBP Establishments
# 0              19334.0
# 1               9839.0
# 2               7297.0
# 20              8277.0
# 5               6853.0

# %%
LowToHighRest_df = combined_df.sort_values(["Total CBP and NES Establishments"], ascending=True).head()
LowToHighRest_df
# Out:
#                       Location  Population  Obesity Percentage  Lower Limit  \
# 266  UnionCounty,NorthCarolina      235908                31.7         25.8
# 268          WarrenCounty,Ohio      232173                27.4         22.9
# 236    MercedCounty,California      274765                28.3         22.3
# 150        PinalCounty,Arizona      447138                33.3         30.7
# 253           WeberCounty,Utah      256359                31.2         29.1
#
#      Upper Limit  Household Total  Median    Mean  NAICS Code  \
# 266         38.0            74763   71588   98685        7225
# 268         32.4            82404   80207  105864        7225
# 236         34.4            77713   47739   70672        7225
# 150         35.8           132352   52555   65692        7225
# 253         33.1            79501   63158   76150        7225
#
#                        NAICS Description  Total CBP and NES Establishments  \
# 266  Restaurants and Other Eating Places                             304.0
# 268  Restaurants and Other Eating Places                             322.0
# 236  Restaurants and Other Eating Places                             324.0
# 150  Restaurants and Other Eating Places                             341.0
# 253  Restaurants and Other Eating Places                             367.0
#
#      CBP Establishments Percentage  NES Establishments Percentage  \
# 266                           86.8                           13.2
# 268                           91.6                            8.4
# 236                           84.3                           15.7
# 150                           80.1                           19.9
# 253                           91.0                            9.0
#
#      CBP Establishments
# 266               264.0
# 268               295.0
# 236               273.0
# 150               273.0
# 253               334.0

# %%
counties = ["UnionCounty,NorthCarolina","WarrenCounty,Ohio" , "MercedCounty,California", "PinalCounty,Arizona", "WeberCounty,Utah",
            "OrangeCounty,California","NewYorkCounty,NewYork", "HarrisCounty,Texas" ,"CookCounty,Illinois", "LosAngelesCounty,California" ]
CBPandNES_establishments = [ 304.0, 322.0, 324.0, 341.0 , 367.0,
                      7802.0, 9260.0, 9494.0,12157.0, 23519.0 ]
HighestRest_df = pd.DataFrame({ "Total CBP and NES Establishments": CBPandNES_establishments}, index=counties)
HighestRest_df
HighestRest_df.plot.bar(rot=90, facecolor = "blue", alpha = 0.5)
plt.title("Number of Restaurants per County (Loweste 5 and highest 5)")
plt.xlabel("Counties")
plt.ylabel("CBP Establishments")
# Out:
# Text(0, 0.5, 'CBP Establishments')

# %%
counties = ["WebbCounty,Texas", "HidalgoCounty,Texas", "CameronCounty,Texas", "BronxCounty,NewYork", "MarionCounty,Florida",
            "ArlingtonCounty,Virginia","SantaClaraCounty,California", "FairfaxCounty,Virginia", "HowardCounty,Maryland", "LoudounCounty,Virginia"]
median_income = [35659, 36176, 37061, 37525, 39383,  
                 110388, 111069, 115717, 120941, 134464 ]
CBPandNES_establishments = [591.0, 1483, 842, 2822, 470,
                         554.0, 3943, 1973 , 503.0, 647.0]
obesity_percentage= [37.7, 34.4, 30.9, 28.8, 30.7, 
                    20,19.2, 21.3,24.8, 22.1 ]
population= [275910, 865939, 423908, 1432132, 359977,
      237521,1937570, 1150795, 323196, 406850 ]
total_df = pd.DataFrame({ "Median Income": median_income, "Restaurants":CBPandNES_establishments, "Obesity Percentage": obesity_percentage, "Population": population}, index= counties)
total_df
# Out:
#                              Median Income  Restaurants  Obesity Percentage  \
# WebbCounty,Texas                     35659        591.0                37.7
# HidalgoCounty,Texas                  36176       1483.0                34.4
# CameronCounty,Texas                  37061        842.0                30.9
# BronxCounty,NewYork                  37525       2822.0                28.8
# MarionCounty,Florida                 39383        470.0                30.7
# ArlingtonCounty,Virginia            110388        554.0                20.0
# SantaClaraCounty,California         111069       3943.0                19.2
# FairfaxCounty,Virginia              115717       1973.0                21.3
# HowardCounty,Maryland               120941        503.0                24.8
# LoudounCounty,Virginia              134464        647.0                22.1
#
#                              Population
# WebbCounty,Texas                 275910
# HidalgoCounty,Texas              865939
# CameronCounty,Texas              423908
# BronxCounty,NewYork             1432132
# MarionCounty,Florida             359977
# ArlingtonCounty,Virginia         237521
# SantaClaraCounty,California     1937570
# FairfaxCounty,Virginia          1150795
# HowardCounty,Maryland            323196
# LoudounCounty,Virginia           406850

# %%
import numpy as np
import matplotlib.pyplot as plt
 

bars1 = total_df["Median Income"]
bars2 = total_df["Population"]
# bars2 = total_df["Restaurants"]
# bars3 = total_df["Obesity Percentage"]
# bars4 = total_df["Population"]

barWidth = 0.25


r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
# r3 = [x + barWidth for x in r2]
# r4 = [x + barWidth for x in r3]



plt.bar(r1,bars1, color = "blue",width=barWidth, label="Median")
# plt.bar(r2,bars2, color = "green",width=barWidth, label="Restaurants")
# plt.bar(r3,bars3, color = "orange", width=barWidth,label="Obesity")
plt.bar(r2,bars4, color = "red", width=barWidth, label="Population")

plt.xlabel('Counties', fontweight='bold')
plt.xticks( [r + barWidth for r in range(len(bars1))],counties, rotation = 45)
plt.title("Populations and Median Income")

plt.legend()
plt.tight_layout()
fig = plt.figure(figsize=(20, 2))
plt.savefig("Figures/Bars_Population_Income.png", bbox_inches="tight")
# plt.savefig("Figures/Bars_Population_Income.jpeg")
plt.show()

# %%
# bars1 = total_df["Median Income"]
# bars2 = total_df["Population"]
bars1 = total_df["Restaurants"]
bars2 = total_df["Obesity Percentage"]


barWidth = 0.25


r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
# r3 = [x + barWidth for x in r2]
# r4 = [x + barWidth for x in r3]



# plt.bar(r1,bars1, color = "blue",width=barWidth, label="Median")
plt.bar(r1,bars1, color = "green",width=barWidth, label="Restaurants")
plt.bar(r2,bars2, color = "orange", width=barWidth,label="Obesity")
# plt.bar(r4,bars4, color = "red", width=barWidth, label="Population")

plt.xlabel('group', fontweight='bold')
plt.xticks( [r + barWidth for r in range(len(bars1))],counties, rotation = "vertical")

plt.legend()
plt.show()
plt.tight_layout()

# %%
plt.bar(counties,median_income, color = "blue", label="Median")
plt.bar(counties,CBP_establishments, color = "green", label="Restaurants")
plt.bar(counties,obesity_percentage, color = "orange", label="Obesity")
plt.bar(counties,population, color = "red", label="Population")



total_df.plot.bar(rot=90, facecolor = "green", alpha = 0.5)
plt.title("Low to High Median Income per County (Loweste 5 and highest 5)")
plt.xlabel("Counties")
plt.ylabel("variables")
plt.show()
plt.layout()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-199-9fb720b159b5> in <module>
#      11 plt.ylabel("variables")
#      12 plt.show()
# ---> 13 plt.layout()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'layout'
